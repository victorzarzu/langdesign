# %%
from openai import OpenAI
import os
import json
import time

client = OpenAI(
   api_key='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',
)

# %%
def write_jsons(response, filename = "prompts.txt"):
    with open(filename, "a") as f:
        for line in response.split("\n"):
            if len(line):
                try:
                    json.loads(line)
                    f.write(line + "\n")
                except:
                    print("incorect line")

# %%
completion = client.chat.completions.create(
  model="gpt-4-1106-preview",
  messages=[
    {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for living room for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                {"input": "An elegant dining room with a long table wtih no candle that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Add a candle on the table.", "output": "An elegant dining room with a long table with candle on it that seats eight, a statement chandelier, and plush velvet chairs.."}
                                {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "emove the bench.", "output": "An organized mudroom with hooks for coats, shelves for shoes, without a bench for seating, and cubbies for storage."}
                                {"input": "A modern living room with a gray sectional couch without a blanket on it, a glass coffee table, and a large flat screen TV on the wall.", "edit": "Add a red throw pillow on the couch.", "output": "A modern living room with a gray sectional couch with a red throw pillow on it, a glass coffee table, and a large flat screen TV on the wall."}
                                {"input": "A traditional living room with a brick fireplace with no clock above, wooden flooring, and an oriental rug.", "edit": "Add a mantel clock above the fireplace.", "output": "A traditional living room with a brick fireplace with a mantel clock above it, wooden flooring, and an oriental rug."}
     '''}
  ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# {"input": "A cozy living room with a beige sofa, a wooden coffee table with a vase of flowers, and a bookshelf full of books.", "edit": "Replace the wooden coffee table with a glass-top coffee table.", "output": "A cozy living room with a beige sofa, a glass-top coffee table with a vase of flowers, and a bookshelf full of books."}
# {"input": "A spacious living room with a leather recliner, a floor lamp, and large windows with sheer curtains.", "edit": "Add a patterned area rug under the recliner.", "output": "A spacious living room with a leather recliner, a floor lamp, and large windows with sheer curtains, with a patterned area rug under the recliner."}
# {"input": "A bright living room with white walls, a blue armchair, and a large potted plant in the corner.", "edit": "Remove the large potted plant.", "output": "A bright living room with white walls and a blue armchair, without a large potted plant in the corner."}
# ...

# %%
for _ in range(50):
    completion = client.chat.completions.create(
    model="gpt-4-1106-preview",
    messages=[
        {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for living room for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                    For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                    Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                    {"input": "An elegant dining room with a long table wtih no candle that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Add a candle on the table.", "output": "An elegant dining room with a long table with candle on it that seats eight, a statement chandelier, and plush velvet chairs.."}
                                    {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                    {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "emove the bench.", "output": "An organized mudroom with hooks for coats, shelves for shoes, without a bench for seating, and cubbies for storage."}
                                    {"input": "A modern living room with a gray sectional couch without a blanket on it, a glass coffee table, and a large flat screen TV on the wall.", "edit": "Add a red throw pillow on the couch.", "output": "A modern living room with a gray sectional couch with a red throw pillow on it, a glass coffee table, and a large flat screen TV on the wall."}'''}
    ]
    )
    write_jsons(completion.choices[0].message.content, filename = "living_room_prompts_gpt4.jsonl")
    time.sleep(2)

# %%
for _ in range(50):
    completion = client.chat.completions.create(
    model="gpt-4-1106-preview",
    messages=[
        {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for bedroom for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                    For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                    Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                    {"input": "An elegant dining room with a long table wtih no candle that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Add a candle on the table.", "output": "An elegant dining room with a long table with candle on it that seats eight, a statement chandelier, and plush velvet chairs.."}
                                    {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                    {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "emove the bench.", "output": "An organized mudroom with hooks for coats, shelves for shoes, without a bench for seating, and cubbies for storage."}
                                    {"input": "A modern living room with a gray sectional couch without a blanket on it, a glass coffee table, and a large flat screen TV on the wall.", "edit": "Add a red throw pillow on the couch.", "output": "A modern living room with a gray sectional couch with a red throw pillow on it, a glass coffee table, and a large flat screen TV on the wall."}'''}
    ]
    )
    write_jsons(completion.choices[0].message.content, filename = "bedrooms_prompts_gpt4.jsonl")
    time.sleep(2)

# %%
for _ in range(30):
    completion = client.chat.completions.create(
    model="gpt-4-1106-preview",
    messages=[
        {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for bathrooms for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                    For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                    Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                    {"input": "An elegant dining room with a long table wtih no candle that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Add a candle on the table.", "output": "An elegant dining room with a long table with candle on it that seats eight, a statement chandelier, and plush velvet chairs.."}
                                    {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                    {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "emove the bench.", "output": "An organized mudroom with hooks for coats, shelves for shoes, without a bench for seating, and cubbies for storage."}
                                    {"input": "A modern living room with a gray sectional couch without a blanket on it, a glass coffee table, and a large flat screen TV on the wall.", "edit": "Add a red throw pillow on the couch.", "output": "A modern living room with a gray sectional couch with a red throw pillow on it, a glass coffee table, and a large flat screen TV on the wall."}'''}
    ]
    )
    write_jsons(completion.choices[0].message.content, filename = "bathrooms_prompts_gpt4.jsonl")
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/victorzarzu/Prompt-based-interior-design-image-editing/data/Generate-interior-design-editing-prompts.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/Users/victorzarzu/Prompt-based-interior-design-image-editing/data/Generate-interior-design-editing-prompts.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> for _ in range(30):
# ----> <a href='vscode-notebook-cell:/Users/victorzarzu/Prompt-based-interior-design-image-editing/data/Generate-interior-design-editing-prompts.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     completion = client.chat.completions.create(
#       <a href='vscode-notebook-cell:/Users/victorzarzu/Prompt-based-interior-design-image-editing/data/Generate-interior-design-editing-prompts.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     model="gpt-4-1106-preview",
# ...

# %%
for _ in range(30):
    completion = client.chat.completions.create(
    model="gpt-4-1106-preview",
    messages=[
        {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for hallway for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                    For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                    Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                    {"input": "An elegant dining room with a long table wtih no candle that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Add a candle on the table.", "output": "An elegant dining room with a long table with candle on it that seats eight, a statement chandelier, and plush velvet chairs.."}
                                    {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                    {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "emove the bench.", "output": "An organized mudroom with hooks for coats, shelves for shoes, without a bench for seating, and cubbies for storage."}
                                    {"input": "A modern living room with a gray sectional couch without a blanket on it, a glass coffee table, and a large flat screen TV on the wall.", "edit": "Add a red throw pillow on the couch.", "output": "A modern living room with a gray sectional couch with a red throw pillow on it, a glass coffee table, and a large flat screen TV on the wall."}'''}
    ]
    )
    write_jsons(completion.choices[0].message.content, filename = "hallways_prompts_gpt4.jsonl")
    time.sleep(2)

# %%
for _ in range(30):
    completion = client.chat.completions.create( 
    model="gpt-4-1106-preview",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a chair in a white background with no other objects or textures in the background image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                        Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                        {"input": "An elegant home office chair with white background with no other objects or textures in the backgroud.", "edit": "Make it fishing chair.", "output": "A fishing chair with white background with no other objects or textures in the backgroud."}
                                        {"input": "An elegant home office chair without a pillow on it in a white background with no other objects or textures in the backgroud.", "edit": "Add a pillow on the chair.", "output": "An elegant home office chair with a pillow and in white background with no other objects or textures in the background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "chairs_white_prompts_gpt4.jsonl")
    time.sleep(2)

# %%
for _ in range(30):
    completion = client.chat.completions.create( 
    model="gpt-4-1106-preview",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a table in a white background with no other objects or textures in the background image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                        Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                        {"input": "An elegant home office chair with white background with no other objects or textures in the backgroud.", "edit": "Make it fishing chair.", "output": "A fishing chair with white background with no other objects or textures in the backgroud."}
                                        {"input": "An elegant home office chair without a pillow on it in a white background with no other objects or textures in the backgroud.", "edit": "Add a pillow on the chair.", "output": "An elegant home office chair with a pillow and in white background with no other objects or textures in the background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "new_tables_single_prompts_gpt4.jsonl")
    time.sleep(2)

# %%
for _ in range(30):
    completion = client.chat.completions.create( 
        model="gpt-4-1106-preview",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a curtains or blinds in image with no other objects or texture in the background except the windows in the image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message and add a white background too all
                                        For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                        Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                        {"input": "Blue vertical blinds on windows with no other objects or textures in the background.", "edit": "Make the blinds green.", "output": "Green vertical blinds on windows with no other objects or textures in the background."}
                                        {"input": "Red vertical blinds on windows with no other objects or textures in the background.", "edit": "Replace the blinds with curtains.", "output": "Red curtains on windows with no other objects or textures in the background."}
                                        {"input": "Red vertical silk curtain on windows with no other objects or textures in the background.", "edit": "Make it velvet.", "output": "Red vertical velvet curtain on windows with no other objects or textures in the background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "new_window_things_single_prompts_gpt4.jsonl")
    time.sleep(2)

# %%
for _ in range(30):
    completion = client.chat.completions.create( 
        model="gpt-4-1106-preview",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a table in a white background with no other objects or textures in the background image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        For the Remove opeartion make sure to specify in the initial description the feature that you want to remove. For example, if you want to remove the drawers of a desk, make sure to specify that the desk has drawers in the initial description.
                                        Additionally, for the Add operation make sure to specify that the feature that you want to add does not exist in the initial descrption. For example, if you want to add drawers to a desk, make sure that you specify that the desk if one without drawers in the initial descrption.
                                        {"input": "Big royal white bed in white background and no other objects or textures in the background.", "edit": "Make it blue.", "output": "Big royal blue bed in white background and no other objects or textures in the background."}
                                        {"input": "Big oak wood bed in white background and no other objects or textures in the background.", "edit": "Make it out of pine wood.", "output": "Big pine wood bed in white background and no other objects or textures in the background."}
                                        {"input": "Big royal white bed in white background and no other objects or textures in the background.", "edit": "Make it a sofa.", "output": "Big white sofa in white background and no other objects or textures in the background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "new_beds_single_prompts.txt")
    time.sleep(2)
