# %%
from openai import OpenAI
import os
import json
import time

client = OpenAI(
   api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
def write_jsons(response, filename = "prompts.txt"):
    with open(filename, "a") as f:
        for line in response.split("\n"):
            if len(line):
                try:
                    json.loads(line)
                    f.write(line + "\n")
                except:
                    print("incorect line")

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for living room for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                {"input": "An elegant dining room with a long table that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Replace the statement chandelier with a modern pendant light.", "output": "An elegant dining room with a long table that seats eight, a modern pendant light, and plush velvet chairs."}
                                {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "Add a designated pet area with a food bowl, water bowl, and bed.", "output": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, cubbies for storage, and a designated pet area with a food bowl, water bowl, and bed."}'''}
  ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# {"input": "A cozy living room with a fireplace, comfortable sofas, and a fluffy rug.", "edit": "Remove the fluffy rug.", "output": "A cozy living room with a fireplace, comfortable sofas, and no rug."}
# {"input": "A modern living room with sleek furniture, floor-to-ceiling windows, and a minimalist coffee table.", "edit": "Replace the floor-to-ceiling windows with French doors.", "output": "A modern living room with sleek furniture, French doors, and a minimalist coffee table."}
# {"input": "A rustic living room with exposed wooden beams, a stone fireplace, and leather armchairs.", "edit": "Add a cowhide rug.", "output": "A rustic living room with exposed wooden beams, a stone fireplace, leather armchairs, and a cowhide rug."}
# ...

# %%
for _ in range(70):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for living room for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        {"input": "An elegant dining room with a long table that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Replace the statement chandelier with a modern pendant light.", "output": "An elegant dining room with a long table that seats eight, a modern pendant light, and plush velvet chairs."}
                                        {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                        {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "Add a designated pet area with a food bowl, water bowl, and bed.", "output": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, cubbies for storage, and a designated pet area with a food bowl, water bowl, and bed."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "living_room_prompts.txt")
    time.sleep(2)

# %%
for _ in range(20):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for bedrooms for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        {"input": "An elegant dining room with a long table that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Replace the statement chandelier with a modern pendant light.", "output": "An elegant dining room with a long table that seats eight, a modern pendant light, and plush velvet chairs."}
                                        {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                        {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "Add a designated pet area with a food bowl, water bowl, and bed.", "output": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, cubbies for storage, and a designated pet area with a food bowl, water bowl, and bed."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "bedrooms_prompts.txt")
    time.sleep(2)

# %%
for _ in range(40):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for bathrooms for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        {"input": "An elegant dining room with a long table that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Replace the statement chandelier with a modern pendant light.", "output": "An elegant dining room with a long table that seats eight, a modern pendant light, and plush velvet chairs."}
                                        {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                        {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "Add a designated pet area with a food bowl, water bowl, and bed.", "output": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, cubbies for storage, and a designated pet area with a food bowl, water bowl, and bed."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "bathrooms_prompts.txt")
    time.sleep(2)
# Out:
# incorect line
# incorect line
# incorect line
# incorect line
# incorect line

# %%
for _ in range(100):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with for hallways for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        {"input": "An elegant dining room with a long table that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Replace the statement chandelier with a modern pendant light.", "output": "An elegant dining room with a long table that seats eight, a modern pendant light, and plush velvet chairs."}
                                        {"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
                                        {"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "Add a designated pet area with a food bowl, water bowl, and bed.", "output": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, cubbies for storage, and a designated pet area with a food bowl, water bowl, and bed."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "hallways_prompts.txt")
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb Cell 10 line 2
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> for _ in range(100):
# ----> <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     completion = client.chat.completions.create(
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>         model="gpt-3.5-turbo",
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>         messages=[
# ...

# %%
for _ in range(100):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a chair in a white background image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
                                        {"input": "An elegant home office chair with white background.", "edit": "Make it fishing chair.", "output": "A fishing chair with white background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "chairs_white_prompts.txt")
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> for _ in range(100):
# ----> <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     completion = client.chat.completions.create(
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a>         model="gpt-3.5-turbo",
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>         messages=[
# ...

# %%
for _ in range(100):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a tables in image in the image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message and add a white background too all
                                        {"input": "An office table out of pine wood with white background.", "edit": "Make the table out of oak wood.", "output": "An office table out of oak wood with white background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "new_tables_single_prompts.txt")
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb Cell 12 line 2
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> for _ in range(100):
# ----> <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a>     completion = client.chat.completions.create(
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>         model="gpt-3.5-turbo",
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-editing-prompts.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>         messages=[
# ...

# %%
for _ in range(100):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a curtains or blinds in image in the image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message and add a white background too all
                                        {"input": "Blue vertical blinds with white background.", "edit": "Make the blinds green.", "output": "Green vertical blinds with white background."}
                                        {"input": "Red vertical blinds with white background.", "edit": "Replace the blinds with curtains.", "output": "Red curtains with white background."}
                                        {"input": "Red vertical silk curtain with white background.", "edit": "Make it velvet.", "output": "Red vertical velvet curtain with white background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "new_window_things_single_prompts.txt")
    time.sleep(2)

# %%
for _ in range(100):
    completion = client.chat.completions.create( 
        model="gpt-3.5-turbo",
        messages=[
            {"role": "user", "content": '''generate JSON objects with other 10 such examples, different than the previous ones, but with just different types of a beds or sofas in image in the image for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message and add a white background too all
                                        {"input": "Big royal white bed with white background.", "edit": "Make it blue.", "output": "Big royal blue bed with white background."}
                                        {"input": "Big oak wood bed with white background.", "edit": "Make it out of pine wood.", "output": "Big pine wood bed with white background."}
                                        {"input": "Big royal white bed with white background.", "edit": "Make it a sofa.", "output": "Big white sofa with white background."}'''}
        ]
    )
    write_jsons(completion.choices[0].message.content, filename = "new_beds_single_prompts.txt")
    time.sleep(2)
