# %%
# !pip install bardapi

# %%
from bardapi import Bard
import os
import json
import time
token = 'cwhde91zts-7eZGwoRBCZkvDqcZDZiwPkAcyYid5ZHyq2R0ezjMGt7rzdcVRkGY8L9FmWg.'

# %%
bard = Bard(token = token)

# %%
res = bard.get_answer('''generate JSON objects with other 10 such examples, but with for living room for interior design editing, but with just 1 feature change at a time (change, addition or removal), different from the previous answers. Respect the most succint format like this: json is on a single line in format {"input:", "edit:", "output:"}, with one json per line, without other text between jsons and without any other message
{"input": "An elegant dining room with a long table that seats eight, a statement chandelier, and plush velvet chairs.", "edit": "Replace the statement chandelier with a modern pendant light.", "output": "An elegant dining room with a long table that seats eight, a modern pendant light, and plush velvet chairs."}
{"input": "A welcoming entryway with a large mirror, a console table with fresh flowers, and a stylish rug.", "edit": "Replace the console table with a floating bench.", "output": "A welcoming entryway with a large mirror, a floating bench with fresh flowers, and a stylish rug."}
{"input": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, and cubbies for storage.", "edit": "Add a designated pet area with a food bowl, water bowl, and bed.", "output": "An organized mudroom with hooks for coats, shelves for shoes, a bench for seating, cubbies for storage, and a designated pet area with a food bowl, water bowl, and bed."}''')['content']
print(res)
# Out:
# Sure, here are 10 more JSON objects with one feature change at a time (change, addition, or removal), different from the previous answers, for living room for interior design editing:
#
# ```json
# {"input": "A cozy living room with a fireplace, a plush sofa, and a large coffee table.", "edit": "Replace the fireplace with a built-in bookshelf.", "output": "A cozy living room with a built-in bookshelf, a plush sofa, and a large coffee table."}
# {"input": "A modern living room with sleek furniture, geometric accents, and large windows.", "edit": "Add a statement rug to define the seating area.", "output": "A modern living room with sleek furniture, geometric accents, large windows, and a statement rug to define the seating area."}
# ...

# %%
def write_jsons(response, filename = "prompts.txt"):
    with open(filename, "a") as f:
        for line in response.split("\n"):
            if len(line):
                try:
                    json.loads(line)
                    f.write(line + "\n")
                except:
                    print("incorect line")
        f.write("\n")

# %%
res = bard.get_answer('''generate another various and different type of living rooms set with 10 with short edit prompts (like add x, replace x with y, remove x) and with jsons on the same line. Make edits with 1 feature at a time (ex. wall, chair, sink, table etc) and remove the numbering on each line''')['content']    
print(res)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-gpu/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# ...

# %%
while True:
    res = bard.get_answer('''generate another various and different type of living rooms set with 10 without repeting the previous ones and with succint edit prompts (like add x, replace x with y, remove x) and no information regarding the feeling and with jsons on the same line. Make edits with 1 feature at a time (ex. wall, chair, sink, table etc) and remove the numbering on each line''')['content']        
    write_jsons(res, filename = "new_living_room_prompts.txt")
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch-gpu/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# ...

# %%
def string_to_json_list(string):
    # Split the string into individual JSON objects
    json_objects = string.split("}")
    
    # Remove the last empty element
    json_objects.pop()
    
    # Convert each JSON object to a dictionary
    json_dicts = []
    for json_object in json_objects:
        json_dict = json.loads(json_object)
        json_dicts.append(json_dict)
    
    return json_dicts

# %%
print(string_to_json_list(res))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> print(string_to_json_list(res))
#
# /Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> json_dicts = []
#      <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> for json_object in json_objects:
# ...

# %%
import openai
os.environ["OPENAI_API_KEY"] = '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'
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
client = openai.OpenAI()

response = client.completions.create(
  model="gpt-3.5-turbo-instruct",
  prompt="Write a tagline for an ice cream shop."
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb Cell 10 line 3
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> client = openai.OpenAI()
# ----> <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> response = client.completions.create(
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a>   model="gpt-3.5-turbo-instruct",
#       <a href='vscode-notebook-cell:/Users/victorzarzu/licenta/data/Generate-interior-design-prompts.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>   prompt="Write a tagline for an ice cream shop."
# ...
